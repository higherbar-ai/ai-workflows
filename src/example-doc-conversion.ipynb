# %% [markdown]
# <a href="https://colab.research.google.com/github/higherbar-ai/ai-workflows/blob/main/src/example-doc-conversion.ipynb" target="_parent"><img alt="Open In Colab" src="https://colab.research.google.com/assets/colab-badge.svg"/></a>
#
# # About this notebook
#
# This notebook provides a simple example of how to use the `ai-workflows` package to convert documents to Markdown format.
#
# ## Configuration
#
# This notebook requires different settings depending on which AI service providers you want to use. If you're running in Google Colab, you configure these settings as "secrets"; just click the key icon in the left sidebar (and, once you create a secret, be sure to click the toggle to give the notebook access to the secret). If you're running this notebook in a different environment, you can set these settings in a `.env` file; the first time you run, it will write out a template `.env` file for you to fill in and direct you to its location. Following are the settings, regardless of the environment.
#
# If you don't have an API key for an AI provider yet, [see here to learn what that is and how to get one](https://www.linkedin.com/pulse/those-genai-api-keys-christopher-robert-l5rie/).
#
# ### OpenAI (direct)
#
# To use OpenAI directly:
#
# * `openai_api_key` - your OpenAI API key (get one from [the OpenAI API key page](https://platform.openai.com/api-keys), and be sure to fund your platform account with at least $5 to allow GPT-4o model access)
# * `openai_model` (optional) - the model to use (defaults to `gpt-4o`)
#
# ### OpenAI (via Microsoft Azure)
#
# To use OpenAI via Microsoft Azure:
#
# * `azure_api_key` - your Azure API key
# * `azure_api_base` - the base URL for the Azure API
# * `azure_api_engine` - the engine to use (a.k.a. the "deployment")
# * `azure_api_version` - the API version to use
#
# ### Anthropic (direct)
#
# To use Anthropic directly:
#
# * `anthropic_api_key` - your Anthropic API key
# * `anthropic_model` - the model to use
#
# ### LangSmith (for tracing)
#
# Optionally, you can add [LangSmith tracing](https://langchain.com/langsmith):
#
# * `langsmith_api_key` - your LangSmith API key
#
# ## Setting up the runtime environment
#
# This next code block installs all necessary Python and system packages into the current environment.
#
# **If you're running in Google Colab and it prompts you to restart the notebook in the middle of the installation steps, just click CANCEL.**

# %%
# install Google Colab Support and ai_workflows package
# %pip install colab-or-not py-ai-workflows[docs]

# download NLTK data
import nltk
nltk.download('punkt', force=True)

# set up our notebook environment (including LibreOffice)
from colab_or_not import NotebookBridge
notebook_env = NotebookBridge(
    system_packages=["libreoffice"],
    config_path="~/.hbai/ai-workflows.env",
    config_template={
        "openai_api_key": "",
        "openai_model": "",
        "azure_api_key": "",
        "azure_api_base": "",
        "azure_api_engine": "",
        "azure_api_version": "",
        "anthropic_api_key": "",
        "anthropic_model": "",
        "langsmith_api_key": "",
    }
)
notebook_env.setup_environment()
# Out:
# Requirement already satisfied: colab-or-not in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (0.4.0)
# Requirement already satisfied: py-ai-workflows[docs] in /Users/crobert/Code/Higher Bar AI/ai-workflows/src (0.26.0)
# Requirement already satisfied: requests~=2.32.3 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from colab-or-not) (2.32.3)
# Requirement already satisfied: python-dotenv~=1.0.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from colab-or-not) (1.0.1)
# Requirement already satisfied: ipython in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from colab-or-not) (8.29.0)
# Requirement already satisfied: ipywidgets in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from colab-or-not) (8.1.5)
# Requirement already satisfied: openai<2.0,>=1.56.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (1.57.4)
# Requirement already satisfied: anthropic[bedrock] in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (0.39.0)
# Requirement already satisfied: tiktoken in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (0.8.0)
# Requirement already satisfied: langsmith<0.2,>=0.1.63 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (0.1.137)
# Requirement already satisfied: tenacity in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (8.5.0)
# Requirement already satisfied: Pillow in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (10.4.0)
# Requirement already satisfied: jsonschema in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (4.23.0)
# Requirement already satisfied: json_repair==0.* in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (0.30.2)
# Requirement already satisfied: unstructured[all-docs] in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (0.16.8)
# Requirement already satisfied: PyMuPDF in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (1.24.12)
# Requirement already satisfied: pymupdf4llm in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (0.0.17)
# Requirement already satisfied: openpyxl in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (3.1.5)
# Requirement already satisfied: nltk==3.9.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (3.9.1)
# Requirement already satisfied: beautifulsoup4>=4.12.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (4.12.3)
# Requirement already satisfied: markdown>=3.5.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (3.7)
# Requirement already satisfied: docling<3.0,>=2.8.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from py-ai-workflows[docs]) (2.8.1)
# Requirement already satisfied: click in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from nltk==3.9.1->py-ai-workflows[docs]) (8.1.7)
# Requirement already satisfied: joblib in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from nltk==3.9.1->py-ai-workflows[docs]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from nltk==3.9.1->py-ai-workflows[docs]) (2024.9.11)
# Requirement already satisfied: tqdm in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from nltk==3.9.1->py-ai-workflows[docs]) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from beautifulsoup4>=4.12.0->py-ai-workflows[docs]) (2.6)
# Requirement already satisfied: certifi>=2024.7.4 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2024.8.30)
# Requirement already satisfied: deepsearch-glm<0.27.0,>=0.26.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (0.26.1)
# Requirement already satisfied: docling-core<3.0.0,>=2.5.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2.5.1)
# Requirement already satisfied: docling-ibm-models<3.0.0,>=2.0.6 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2.0.6)
# Requirement already satisfied: docling-parse<3.0.0,>=2.0.5 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2.1.2)
# Requirement already satisfied: easyocr<2.0,>=1.7 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (1.7.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (1.2.0)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (0.26.1)
# Requirement already satisfied: lxml<6.0.0,>=4.0.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (5.3.0)
# Requirement already satisfied: marko<3.0.0,>=2.1.2 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2.1.2)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2.2.3)
# Requirement already satisfied: pydantic<2.10,>=2.0.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2.9.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2.6.1)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.30.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (4.30.0)
# Requirement already satisfied: python-docx<2.0.0,>=1.1.2 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (1.1.2)
# Requirement already satisfied: python-pptx<2.0.0,>=1.0.2 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (1.0.2)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (1.3.0)
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (1.14.1)
# Requirement already satisfied: typer<0.13.0,>=0.12.5 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling<3.0,>=2.8.1->py-ai-workflows[docs]) (0.12.5)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from langsmith<0.2,>=0.1.63->py-ai-workflows[docs]) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from langsmith<0.2,>=0.1.63->py-ai-workflows[docs]) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from langsmith<0.2,>=0.1.63->py-ai-workflows[docs]) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from openai<2.0,>=1.56.1->py-ai-workflows[docs]) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from openai<2.0,>=1.56.1->py-ai-workflows[docs]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from openai<2.0,>=1.56.1->py-ai-workflows[docs]) (0.6.1)
# Requirement already satisfied: sniffio in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from openai<2.0,>=1.56.1->py-ai-workflows[docs]) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from openai<2.0,>=1.56.1->py-ai-workflows[docs]) (4.12.2)
# Requirement already satisfied: et-xmlfile in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from openpyxl->py-ai-workflows[docs]) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from requests~=2.32.3->colab-or-not) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from requests~=2.32.3->colab-or-not) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from requests~=2.32.3->colab-or-not) (2.2.3)
# Requirement already satisfied: boto3>=1.28.57 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from anthropic[bedrock]->py-ai-workflows[docs]) (1.34.162)
# Requirement already satisfied: botocore>=1.31.57 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from anthropic[bedrock]->py-ai-workflows[docs]) (1.34.162)
# Requirement already satisfied: decorator in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from ipython->colab-or-not) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from ipython->colab-or-not) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from ipython->colab-or-not) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from ipython->colab-or-not) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from ipython->colab-or-not) (2.18.0)
# Requirement already satisfied: stack-data in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from ipython->colab-or-not) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from ipython->colab-or-not) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from ipython->colab-or-not) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from ipywidgets->colab-or-not) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from ipywidgets->colab-or-not) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from ipywidgets->colab-or-not) (3.0.13)
# Requirement already satisfied: attrs>=22.2.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from jsonschema->py-ai-workflows[docs]) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from jsonschema->py-ai-workflows[docs]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from jsonschema->py-ai-workflows[docs]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from jsonschema->py-ai-workflows[docs]) (0.20.0)
# Requirement already satisfied: chardet in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (5.2.0)
# Requirement already satisfied: python-magic in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.4.27)
# Requirement already satisfied: emoji in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (2.14.0)
# Requirement already satisfied: dataclasses-json in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.6.7)
# Requirement already satisfied: python-iso639 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (2024.10.22)
# Requirement already satisfied: langdetect in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.0.9)
# Requirement already satisfied: numpy<2 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.26.4)
# Requirement already satisfied: rapidfuzz in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (3.10.1)
# Requirement already satisfied: backoff in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (2.2.1)
# Requirement already satisfied: unstructured-client in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.26.1)
# Requirement already satisfied: wrapt in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.16.0)
# Requirement already satisfied: psutil in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (6.1.0)
# Requirement already satisfied: python-oxmsg in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.0.1)
# Requirement already satisfied: html5lib in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.1)
# Requirement already satisfied: onnx in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.17.0)
# Requirement already satisfied: pdfminer.six in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (20231228)
# Requirement already satisfied: pypandoc in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.14)
# Requirement already satisfied: pypdf in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (5.0.1)
# Requirement already satisfied: pdf2image in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.17.0)
# Requirement already satisfied: pi-heif in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.20.0)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.3.13)
# Requirement already satisfied: google-cloud-vision in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (3.8.0)
# Requirement already satisfied: pikepdf in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (9.3.0)
# Requirement already satisfied: xlrd in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (2.0.1)
# Requirement already satisfied: unstructured-inference==0.8.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.8.1)
# Requirement already satisfied: effdet in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.4.1)
# Requirement already satisfied: networkx in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (3.4.2)
# Requirement already satisfied: layoutparser in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.3.4)
# Requirement already satisfied: python-multipart in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.0.12)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (4.10.0.84)
# Requirement already satisfied: onnxruntime>=1.17.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.19.2)
# Requirement already satisfied: matplotlib in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (3.9.2)
# Requirement already satisfied: torch in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (2.5.0)
# Requirement already satisfied: timm in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.0.11)
# Requirement already satisfied: transformers>=4.25.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (4.46.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from boto3>=1.28.57->anthropic[bedrock]->py-ai-workflows[docs]) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from boto3>=1.28.57->anthropic[bedrock]->py-ai-workflows[docs]) (0.10.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from botocore>=1.31.57->anthropic[bedrock]->py-ai-workflows[docs]) (2.8.2)
# Requirement already satisfied: docutils!=0.21 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (0.21.2)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (13.9.3)
# Requirement already satisfied: tabulate>=0.8.9 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (0.9.0)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling-core<3.0.0,>=2.5.1->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (1.1.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling-core<3.0.0,>=2.5.1->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (6.0.2)
# Requirement already satisfied: jsonlines<4.0.0,>=3.1.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling-ibm-models<3.0.0,>=2.0.6->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (3.1.0)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.6.0.66 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling-ibm-models<3.0.0,>=2.0.6->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (4.10.0.84)
# Requirement already satisfied: torchvision<1,>=0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from docling-ibm-models<3.0.0,>=2.0.6->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (0.20.0)
# Requirement already satisfied: scikit-image in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from easyocr<2.0,>=1.7->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (0.24.0)
# Requirement already satisfied: python-bidi in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from easyocr<2.0,>=1.7->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (0.6.3)
# Requirement already satisfied: Shapely in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from easyocr<2.0,>=1.7->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2.0.6)
# Requirement already satisfied: pyclipper in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from easyocr<2.0,>=1.7->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (1.3.0.post6)
# Requirement already satisfied: ninja in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from easyocr<2.0,>=1.7->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (1.11.1.2)
# Requirement already satisfied: httpcore==1.* in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2,>=0.1.63->py-ai-workflows[docs]) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2,>=0.1.63->py-ai-workflows[docs]) (0.14.0)
# Requirement already satisfied: filelock in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from huggingface_hub<1,>=0.23->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from huggingface_hub<1,>=0.23->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from huggingface_hub<1,>=0.23->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (24.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from jedi>=0.16->ipython->colab-or-not) (0.8.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from pandas<3.0.0,>=2.1.4->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from pandas<3.0.0,>=2.1.4->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2024.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython->colab-or-not) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->colab-or-not) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from pydantic<2.10,>=2.0.0->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from pydantic<2.10,>=2.0.0->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2.23.4)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from python-pptx<2.0.0,>=1.0.2->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (3.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from typer<0.13.0,>=0.12.5->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (1.5.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from dataclasses-json->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (3.23.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from dataclasses-json->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.9.0)
# Requirement already satisfied: pycocotools>=2.0.2 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from effdet->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (2.0.8)
# Requirement already satisfied: omegaconf>=2.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from effdet->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (2.21.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from google-cloud-vision->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (2.35.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from google-cloud-vision->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from google-cloud-vision->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (5.28.3)
# Requirement already satisfied: six>=1.9 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from html5lib->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.16.0)
# Requirement already satisfied: webencodings in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from html5lib->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.5.1)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from pdfminer.six->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (43.0.3)
# Requirement already satisfied: Deprecated in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from pikepdf->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.2.14)
# Requirement already satisfied: olefile in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from python-oxmsg->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.47)
# Requirement already satisfied: executing>=1.2.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from stack-data->ipython->colab-or-not) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from stack-data->ipython->colab-or-not) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from stack-data->ipython->colab-or-not) (0.2.3)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured-client->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.2.0)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured-client->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.0.6)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from unstructured-client->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.6.0)
# Requirement already satisfied: cffi>=1.12 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.17.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.65.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.67.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.67.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (4.9)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from omegaconf>=2.0->effdet->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (4.9.3)
# Requirement already satisfied: coloredlogs in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (24.3.25)
# Requirement already satisfied: sympy in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (3.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from rich<14.0.0,>=13.7.0->deepsearch-glm<0.27.0,>=0.26.1->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (3.0.0)
# Requirement already satisfied: safetensors in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from timm->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.4.5)
# Requirement already satisfied: jinja2 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from torch->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from sympy->onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.3.0)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (1.0.0)
# Requirement already satisfied: iopath in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.1.10)
# Requirement already satisfied: pdfplumber in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.11.4)
# Requirement already satisfied: imageio>=2.33 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (0.4)
# Requirement already satisfied: pycparser in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->deepsearch-glm<0.27.0,>=0.26.1->docling<3.0,>=2.8.1->py-ai-workflows[docs]) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (0.6.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (10.0)
# Requirement already satisfied: portalocker in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from iopath->layoutparser->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (2.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/crobert/Code/Higher Bar AI/ai-workflows/.venv/lib/python3.11/site-packages (from jinja2->torch->unstructured-inference==0.8.1->unstructured[all-docs]; extra == "docs"->py-ai-workflows[docs]) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [nltk_data] Downloading package punkt to /Users/crobert/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ==> Auto-updating Homebrew...
# Adjust how often this is run with HOMEBREW_AUTO_UPDATE_SECS or disable with
# HOMEBREW_NO_AUTO_UPDATE. Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Downloading https://ghcr.io/v2/homebrew/portable-ruby/portable-ruby/blobs/sha256:d9faa506c014dedc0b034a68103ba75c9a58242f4d6c67b6ca0f649c39602bcf
# ######################################################################## 100.0%
# ==> Pouring portable-ruby-3.3.7.arm64_big_sur.bottle.tar.gz
# ==> Auto-updated Homebrew!
# Updated 3 taps (caskroom/cask, homebrew/core and homebrew/cask).
# ==> New Formulae
# alive2
# asciigen
# azure-storage-blobs-cpp
# azure-storage-common-cpp
# beanquery
# binocle
# bold
# c2patool
# cargo-cache
# cargo-cyclonedx
# cargo-hack
# cargo-update
# cdncheck
# chaos-client
# codeberg-cli
# diary
# dpic
# fastbuild
# fish-lsp
# guile-fibers
# hevi
# html2markdown
# json2hcl
# kube-bench
# libcotp
# percona-server@8.0
# percona-xtrabackup@8.0
# perl-dbd-mysql
# pkgx
# pnpm@9
# prism-cli
# rmtrash
# shepherd
# sshx
# superhtml
# tach
# tfocus
# tinysparql
# xtermcontrol
# zigup
# ==> New Casks
# amiberry
# amiberry
# cpu-info
# cpu-info
# display-pilot
# display-pilot
# flowvision
# flowvision
# font-42dot-sans
# font-42dot-sans
# font-atkinson-hyperlegible-mono
# font-atkinson-hyperlegible-mono
# font-atkinson-hyperlegible-next
# font-atkinson-hyperlegible-next
# font-liter
# font-liter
# font-pixel-code
# font-pixel-code
# helpwire-operator
# helpwire-operator
# istherenet
# istherenet
# jottacloud
# jottacloud
# lyric-fever
# lyric-fever
# mihomo-party
# mihomo-party
# spectrolite
# spectrolite
# stratoshark@dev
# stratoshark@dev
# tdr-molotok
# tdr-molotok
# tdr-prism
# tdr-prism
# termora
# termora
# windowkeys
# windowkeys
#
# You have 26 outdated formulae and 3 outdated casks installed.
# Dependencies installed successfully.
# Warning: Not upgrading libreoffice, the latest version is already installed

# %% [markdown]
# ## Initializing
#
# The next code block initializes the notebook by loading settings and initializing the LLM interface.

# %%
from ai_workflows.llm_utilities import LLMInterface
from ai_workflows.document_utilities import DocumentInterface

# read all supported settings
openai_api_key = notebook_env.get_setting('openai_api_key')
openai_model = notebook_env.get_setting('openai_model', 'gpt-4o')
azure_api_key = notebook_env.get_setting('azure_api_key')
azure_api_base = notebook_env.get_setting('azure_api_base')
azure_api_engine = notebook_env.get_setting('azure_api_engine')
azure_api_version = notebook_env.get_setting('azure_api_version')
anthropic_api_key = notebook_env.get_setting("anthropic_api_key")
anthropic_model = notebook_env.get_setting("anthropic_model")
langsmith_api_key = notebook_env.get_setting('langsmith_api_key')

# complain if we don't have the bare minimum to run
if (not openai_api_key
        and not (azure_api_key and azure_api_base and azure_api_engine and azure_api_version)
        and not (anthropic_api_key and anthropic_model)):
    raise Exception('We need settings set for OpenAI access (direct or via Azure) or for Anthropic access (direct). See the instructions above for more details.')

# initialize LLM interface
llm = LLMInterface(openai_api_key=openai_api_key, openai_model=openai_model, azure_api_key=azure_api_key, azure_api_base=azure_api_base, azure_api_engine=azure_api_engine, azure_api_version=azure_api_version, temperature = 0.0, total_response_timeout_seconds=600, number_of_retries=2, seconds_between_retries=5, langsmith_api_key=langsmith_api_key, anthropic_api_key=anthropic_api_key, anthropic_model=anthropic_model)

# initialize our document processor
doc_interface = DocumentInterface(llm_interface=llm)

# report success
print("Initialization successful.")
# Out:
# Initialization successful.

# %% [markdown]
# ## Document selection and conversion
#
# This next code block prompts you to upload or select one or more files to convert to markdown, then it converts them to Markdown.
#
# ### Where to find output files
#
# If you're running in Google Colab, output files are saved into the content folder. Find, view, and download them by clicking on the folder icon in the left sidebar.
#
# If you're running elsewhere, output files are saved into an `ai-workflows` subdirectory created off of your user home directory.

# %%
import os

# prompt for one or more files
files_to_convert = notebook_env.get_input_files("File(s) to convert to Markdown")

# output files to ~/ai-workflows directory if local, otherwise /content if Google Colab
output_path_prefix = notebook_env.get_output_dir(not_colab_dir="~/ai-workflows", colab_subdir="")

# process files one-by-one
for file_to_convert in files_to_convert:
    print(f'Processing {file_to_convert}...')
    
    # convert to markdown
    markdown = doc_interface.convert_to_markdown(file_to_convert)

    # write the markdown to the output directory
    output_path = os.path.join(output_path_prefix, os.path.splitext(os.path.basename(file_to_convert))[0] + '.md')
    with open(output_path, 'w') as f:
        f.write(markdown)

    print(f"Conversion complete. Markdown saved to {output_path}")
# Out:
# 2025-01-24 09:59:15.660 Python[55794:40820285] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-01-24 09:59:16.148 Python[55794:40820285] The class 'NSOpenPanel' overrides the method identifier.  This method is implemented by class 'NSWindow'
# Processing /Users/crobert/Library/CloudStorage/GoogleDrive-crobert@higherbar.ai/Shared drives/Team - Product - External shares/Client work/Dobility/AI for survey innovation/Google.org GenAI accelerator - Application questions.pdf...
# Conversion complete. Markdown saved to /Users/crobert/ai-workflows/Google.org GenAI accelerator - Application questions.md
